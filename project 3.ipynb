# %% [raw]
# Project 3  for insurance data

# %%
import pandas as pd

# %%
df = pd.read_csv("insurance_data_200.csv")

# %%
df.head()
# Out:
#    age  insurance_bought
# 0   56                 1
# 1   69                 1
# 2   46                 1
# 3   32                 0
# 4   60                 1

# %%
df.isnull().sum()
# Out:
# age                 0
# insurance_bought    0
# dtype: int64

# %%
x = df[["age"]]

# %%
y = df.insurance_bought

# %%
import matplotlib.pyplot as plt

# %%
plt.title(" Insurance bought ")
plt.scatter(x,y,color="red")
plt.show()

# %%
# sigmoid function

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
a1 = int(input("enter the age : "))
if model.predict([[a1]])[0] == 0:
    print("no")
else:
    print("yes")
# Out:
# enter the age : 21
# no

# %%
model.predict(x) == y
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 195     True
# 196     True
# 197     True
# 198     True
# 199     True
# Name: insurance_bought, Length: 200, dtype: bool
